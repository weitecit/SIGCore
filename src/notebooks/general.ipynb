# %%
import mongo_api as mapi

gdf = mapi.get_parcelario('Juan Bautista',only_operating=False)
# Out:
# ENVIRONMENT set to -> local
# ---------------------------------------------------------------------------
# FieldNotFound                             Traceback (most recent call last)
# Cell In[1], line 3
#       1 import mongo_api as mapi
#       2
# ----> 3 gdf = mapi.get_parcelario('Juan Bautista',only_operating=False)
#
# File C:\Repos\SIGCore\src\mongo_api.py:36, in get_parcelario(field_name, client, only_operating)
#      34 features = find_field_plots(field_name, client)
#      35 if len(features)<=0:
# ---> 36     raise FieldNotFound(f"Field '{field_name}' not found in database")
#      37 gdf = _mongo_to_gdf(features).to_crs(4258)
#      38 return gdf[gdf['operating']] if only_operating else gdf
#
# FieldNotFound: Field 'Juan Bautista' not found in database
