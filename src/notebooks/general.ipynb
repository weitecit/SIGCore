# %%
import mongo_api
mongo_api.get_weifield_samplers()
# Out:
# ENVIRONMENT set to -> local
# {'67040ebdd72edb5d585d188a': 'Mario',
#  '67fe2dbf2dbd59f43fd86111': 'Pablo Parres',
#  '69ca5748a8ee1914ca2e25ba': 'Ana',
#  '6a2fe52531fdda452ace64b7': 'Adrián Rodríguez Baudru'}

# %%
gdf = mongo_api.get_weifield_points(['67fe2dbf2dbd59f43fd86111'])

# %%
gdf[gdf.duplicated(subset=['geometry'], keep=False)]['created_by'].value_counts()
# Out:
# created_by
# system                    106
# pablo.parres@weitec.es     12
# Name: count, dtype: int64
