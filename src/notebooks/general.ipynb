# %%
import mongo_api as mapi


mapi.db.points.distinct('crs')
# Out:
# [{'type': 'name', 'properties': {'name': 'EPSG:32630'}},
#  {'type': 'name', 'properties': {'name': 'EPSG:4326'}}]

# %%
result1 = mapi.db.points.updateMany({'crs':{'type': 'name', 'properties': {'name': 'EPSG:32630'}}},
                          {'$set':{'crs':'EPSG:32630'}})
result2 = mapi.db.points.updateMany({'crs':{'type': 'name', 'properties': {'name': 'EPSG:4326'}}},
                          {'$set':{'crs':'EPSG:4326'}})
# Out:
# {'_id': ObjectId('68641d26c6caf9c8ca47b906'),
#  'type': 'Feature',
#  'geometry': {'type': 'Point',
#   'coordinates': [672969.1773677851, 4222013.613697218]},
#  'properties': {'title': 'rotura',
#   'confidence': 0.6837146282196045,
#   'comments': '',
#   'severity': 0,
#   'use_case': 'roturas_hidricas',
#   'hide': False,
#   'position_source': None,
#   'horizontal_accuracy': None,
#   'parcel_id': '67e17ae218156b896d655e5a',
#   'parcel_name': None,
#   'source_version': '0.1',
#   'source_name': 'MLCore',
#   'sampled_at': datetime.datetime(2025, 7, 1, 17, 38, 46, 977000),
#   'created_at': datetime.datetime(2025, 7, 1, 17, 38, 46, 977000),
#   'created_by': 'roturas_model',
#   'photos_ids': [],
#   'verified_at': None,
#   'verified_by': None,
#   'use_case_detail': 'roturas_hidricas',
#   'validated_by_staff': ''},
#  'crs': {'type': 'name', 'properties': {'name': 'EPSG:32630'}},
#  'created_by': {'user': '630eecff5a189ef44e8ce23a',
# ...
