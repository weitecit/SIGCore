# %%
import requests

form_data = {
  "plots": [
        {
            "field": "Finca El Olivar",
            "crop": "limón",
            "province": 2,
            "municipality": 13,
            "aggregate": 0,
            "zone": 0,
            "polygon": 19,
            "plot_number": 20,
            "enclosure": 1,
            "area_ha": 8.75,
            "cadastral_ref": "51016A118000230000BP"
        },
        {
            "field": "Finca El Olivar",
            "crop": "limón",
            "province": 12,
            "municipality": 11,
            "aggregate": 0,
            "zone": 0,
            "polygon": 3,
            "plot_number": 112,
            "enclosure": 25,
            "area_ha": 12.5,
            "cadastral_ref": "28079A003001500042AB"
        },
        {
            "field": "Finca El Olivar",
            "crop": "limón",
            "province": 12,
            "municipality": 11,
            "aggregate": 0,
            "zone": 0,
            "polygon": 4,
            "plot_number": 114,
            "enclosure": 26,
            "area_ha": 15.5,
            "cadastral_ref": "88079A003001500042AB"
        }
    ]
}


url = f"http://localhost:8000/api/v2/plots/polygonize"
response = requests.post(url, json=form_data)
print(response.json())
# Out:
# {'polygonized_data': {'type': 'FeatureCollection', 'features': [{'id': '3584', 'type': 'Feature', 'properties': {'provincia': 2, 'municipio': 13, 'agregado': 0, 'zona': 0, 'poligono': 19, 'parcela': 20, 'recinto': 1, 'dn_surface': 44609.974267237914, 'pendiente_media': 15, 'altitud': 725, 'csp': None, 'coef_regadio': 0.0, 'uso_sigpac': 'TA', 'incidencias': '12', 'region': 1.0, 'field': 'Finca El Olivar', 'crop': 'limón', 'operating': True, 'cadastral_ref': '51016A118000230000BP'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-1.243682931359585, 39.256624931771306], [-1.2435864682211857, 39.25761141813093], [-1.2436794252092793, 39.25758627158173], [-1.2437290469172029, 39.257576631554315], [-1.2437629944652615, 39.25757495433539], [-1.2437933377947412, 39.25757755272553], [-1.243892329753478, 39.25759540534215], [-1.2439583808307875, 39.25761929376762], [-1.2440250186413537, 39.25766061655271], [-1.2440573744659051, 39.25768760628254], [-1.2441282040664974, 39.257762038425334], 
# ...

# %%
import catastro

catastro._download_municipality(2, 13, 2025)
# Out:
# c:\Users\danie\Documents\SIGCore\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.fega.gob.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ENVIRONMENT set to -> local
# Municipality 13 of province ALBACETE found.
# ...
# File extracted at C:\Users\danie\Documents\SIGCore\provinces
# <Response [200]>

# %%
import requests

url = "http://localhost:8000/health"
response = requests.get(url)
print(response.json())
# Out:
# {'status': 'healthy', 'SIGPAC': 200, 'MongoDB': {'status': 'unhealthy', 'error': "weitec-db-pro-shard-00-02.sgtmd.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),weitec-db-pro-shard-00-00.sgtmd.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),weitec-db-pro-shard-00-01.sgtmd.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6a4b715089980fecffb4a2ed, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('weitec-db-pro-shard-00-00.sgtmd.mongodb.net', 27017) server_type: Unknown, rtt: None, error=NetworkTimeout('weitec-db-pro-shard-00-00.sgtmd.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('weitec-db-pro-shard-00-01.sgtmd.mongodb.net', 27017) server_type: Un
# ...
