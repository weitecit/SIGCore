# %%
import requests

parcel_id = '679a4474c78a2b7049ce39af'

url = f"https://core-gateway-dev-313133795617.europe-west1.run.app/sig/api/v1/plots/679a4474c78a2b7049ce39af"
headers = {
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ0ZXN0LXVzZXIifQ.R38A63mjDK0D1ttMXuwloKUr2CVewVfdzbDdxrmfKdg"
}
response = requests.get(url, headers=headers)
print(response.json())

# %%
import requests

url = "http://localhost:8000/health"
response = requests.get(url)
print(response.json())
# Out:
# {'status': 'healthy', 'SIGPAC': 200, 'MongoDB': {'ok': 1}}
